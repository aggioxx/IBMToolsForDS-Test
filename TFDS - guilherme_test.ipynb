# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Guilherme Aggio**
# Currently as a banker, my goal is move to the Data Science team.

# %% [markdown]
# *I'm interessed in Data Science mainly because i see it as the future of humanity, although all jobs are really important, data science can comunicate with mostly all companies in all areas. This leads us to the most promising carrer*

# %% [markdown]
# ### The code should calculate the hypot of a triangle (3,4,5). The correct answer is 5 btw

# %%
import math
co = 3
ca = 4
calc = (co ** 2) + (ca ** 2)
res = math.sqrt(calc)
#hi = math.hypot(ca, co)
print('A hipotenusa tem {}cm'.format(res))
# Out:
# A hipotenusa tem 5.0cm

# %% [markdown]
# * Python
# * Machine Learning
# * AWS
#
# ***
#
# DATA SCIENCE ROCKS!
#
# ***
#
# If you like the content, visit my Github at <a href="https://github.com/aggioxx/" target="_blank">aggioxx </a>.
